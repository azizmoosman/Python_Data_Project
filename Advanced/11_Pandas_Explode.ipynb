# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
data = {
    'job_title_short': ['Data Analyst', 'Data Scientist', 'Data Engineer'],
    'job_skills': [['excel', 'sql', 'python'], ['python', 'r'], ['aws', 'python', 'airflow']]
}

df_skills = pd.DataFrame(data)

df_skills
# Out:
#   job_title_short              job_skills
# 0    Data Analyst    [excel, sql, python]
# 1  Data Scientist             [python, r]
# 2   Data Engineer  [aws, python, airflow]

# %%
df_skills.explode('job_skills')
# Out:
#   job_title_short job_skills
# 0    Data Analyst      excel
# 0    Data Analyst        sql
# 0    Data Analyst     python
# 1  Data Scientist     python
# 1  Data Scientist          r
# 2   Data Engineer        aws
# 2   Data Engineer     python
# 2   Data Engineer    airflow

# %%
df_skills.explode('job_skills').value_counts('job_skills')
# Out:
# job_skills
# python     3
# excel      1
# sql        1
# r          1
# aws        1
# airflow    1
# Name: count, dtype: int64

# %%
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else(x))

# %%
df[['job_title_short', 'job_skills']]. head(5)
# Out:
#         job_title_short                                         job_skills
# 0  Senior Data Engineer                                                NaN
# 1          Data Analyst         [r, python, sql, nosql, power bi, tableau]
# 2         Data Engineer  [python, sql, c#, azure, airflow, dax, docker,...
# 3         Data Engineer  [python, c++, java, matlab, aws, tensorflow, k...
# 4         Data Engineer  [bash, python, oracle, aws, ansible, puppet, j...

# %%
df_exploded = df.explode('job_skills')

# %%
df_exploded
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# 1               Data Analyst
# ...                      ...
# 785739         Data Engineer
# 785739         Data Engineer
# 785739         Data Engineer
# 785740     Software Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# 1                                            Data Analyst
# ...                                                   ...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
df_exploded['job_skills'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='job_skills'>

# %%
# now lets do that by each job on its own 

skills_of_jobs = df_exploded.groupby(['job_title_short','job_skills']).size()

# %%
type(skills_of_jobs)
# Out:
# pandas.Series

# %%
#this is a series, but we better put it as a df, so we will need to reset the index
df_skills_jobs = skills_of_jobs.reset_index(name='skill_count')

# %%
type(df_skills_jobs)
# Out:
# pandas.DataFrame

# %%
df_skills_jobs
# Out:
#         job_title_short job_skills  skill_count
# 0      Business Analyst    airflow          318
# 1      Business Analyst   airtable           17
# 2      Business Analyst    alteryx         1078
# 3      Business Analyst    angular           87
# 4      Business Analyst    ansible          120
# ...                 ...        ...          ...
# 2251  Software Engineer      wrike            4
# 2252  Software Engineer        wsl           13
# 2253  Software Engineer    xamarin           35
# 2254  Software Engineer       yarn          145
# 2255  Software Engineer       zoom          229
#
# [2256 rows x 3 columns]

# %%
df_skills_jobs = df_skills_jobs.sort_values(by='skill_count', ascending=False)

# %%
df_skills_jobs
# Out:
#             job_title_short   job_skills  skill_count
# 1066         Data Scientist       python       113711
# 865           Data Engineer          sql       113130
# 830           Data Engineer       python       108022
# 625            Data Analyst          sql        92428
# 1101         Data Scientist          sql        78982
# ...                     ...          ...          ...
# 266          Cloud Engineer       delphi            1
# 1920  Senior Data Scientist  objective-c            1
# 1400    Senior Data Analyst      couchdb            1
# 298          Cloud Engineer      haskell            1
# 631            Data Analyst         suse            1
#
# [2256 rows x 3 columns]

# %%
# to have the top ten skills for each job on its own 

job_title = 'Data Analyst'
top_skills = 10

df_skills_final = df_skills_jobs[df_skills_jobs['job_title_short'] == job_title].head(top_skills)
df_skills_final.plot(kind='barh', x='job_skills', y='skill_count')

#to have the y axis inverted, we can use the gca().invert_yaxis() from the plt
plt.gca().invert_yaxis()
plt.title(f'Top {top_skills} Skills for {job_title}s')
plt.xlabel('Job Posting Count')
plt.ylabel('')
plt.legend().set_visible(False)
plt.show()
